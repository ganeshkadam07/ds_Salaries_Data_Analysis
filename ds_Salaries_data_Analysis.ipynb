# %%
import pandas as pd

# %%
data=pd.read_csv('ds_salaries.csv')

# %%
data
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT               Data Analyst
# 1          2022               EN              FT             Data Scientist
# 2          2023               MI              FT               Data Analyst
# 3          2023               MI              FT               Data Analyst
# 4          2023               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 1943       2020               SE              FT             Data Scientist
# 1944       2021               MI              FT   Principal Data Scientist
# 1945       2020               EN              FT             Data Scientist
# 1946       2020               EN              CT      Business Data Analyst
# 1947       2021               SE              FT       Data Science Manager
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1948 entries, 0 to 1947
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           1948 non-null   int64
#  1   experience_level    1948 non-null   object
#  2   employment_type     1948 non-null   object
#  3   job_title           1948 non-null   object
#  4   salary              1948 non-null   int64
#  5   salary_currency     1948 non-null   object
#  6   salary_in_usd       1948 non-null   int64
#  7   employee_residence  1948 non-null   object
#  8   remote_ratio        1948 non-null   int64
#  9   company_location    1948 non-null   object
#  10  company_size        1948 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 167.5+ KB

# %%
data.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
data.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  1948.000000  1.948000e+03    1948.000000   1948.000000
# mean   2021.809548  2.155337e+05  127525.004620     56.878850
# std       0.490455  9.133814e+05   62267.970302     47.499485
# min    2020.000000  5.000000e+03    5000.000000      0.000000
# 25%    2022.000000  8.700000e+04   82690.000000      0.000000
# 50%    2022.000000  1.300000e+05  129300.000000    100.000000
# 75%    2022.000000  1.750000e+05  167000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# ...
#      ------------------------------------ 293.3/293.3 kB 624.8 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
sns.barplot(x='salary',y='salary_in_usd',data=data)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='salary_in_usd'>

# %%
sns.barplot(x='job_title',y='salary',data=data)
# Out:
# <AxesSubplot:xlabel='job_title', ylabel='salary'>

# %%
sns.scatterplot(x='remote_ratio',y='salary',data=data)
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='salary'>

# %%
sns.countplot(x='salary_in_usd',data=data)
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='count'>

# %%
sns.countplot(x='salary',data=data)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
sns.displot(x='work_year',data=data)

# %%
sns.boxplot(data['work_year'])
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data['experience_level'])
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='Count'>

# %%
sns.boxplot(x='salary_in_usd',data=data)
# Out:
# <AxesSubplot:xlabel='salary_in_usd'>

# %%
sns.kdeplot(x='salary_in_usd',data=data)
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='Density'>

# %%
# Bivariate Plots
sns.boxplot(x = 'work_year', y = 'salary_in_usd', data =data)
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='salary_in_usd'>

# %%
sns.boxplot(x = 'experience_level', y = 'salary_in_usd', data =data)
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='salary_in_usd'>

# %%
sns.boxplot(x = 'experience_level', y = 'salary_in_usd',hue = "work_year" ,data =data)
# Out:
# <AxesSubplot:xlabel='experience_level', ylabel='salary_in_usd'>

# %%
data.corr()
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.113577       0.219340     -0.098063
# salary         -0.113577  1.000000      -0.061249      0.021274
# salary_in_usd   0.219340 -0.061249       1.000000      0.000859
# remote_ratio   -0.098063  0.021274       0.000859      1.000000

# %%
x=data.corr()
sns.heatmap(x,annot=True)
# Out:
# <AxesSubplot:>
